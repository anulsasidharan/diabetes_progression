# %%
### Diabetes Progression Predection

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
pd.read_csv("diabetes.csv")
# Out:
#      AGE  SEX   BMI      BP   S1     S2    S3    S4      S5   S6    Y
# 0     59    2  32.1  101.00  157   93.2  38.0  4.00  4.8598   87  151
# 1     48    1  21.6   87.00  183  103.2  70.0  3.00  3.8918   69   75
# 2     72    2  30.5   93.00  156   93.6  41.0  4.00  4.6728   85  141
# 3     24    1  25.3   84.00  198  131.4  40.0  5.00  4.8903   89  206
# 4     50    1  23.0  101.00  192  125.4  52.0  4.00  4.2905   80  135
# ..   ...  ...   ...     ...  ...    ...   ...   ...     ...  ...  ...
# 437   60    2  28.2  112.00  185  113.8  42.0  4.00  4.9836   93  178
# 438   47    2  24.9   75.00  225  166.0  42.0  5.00  4.4427  102  104
# 439   60    2  24.9   99.67  162  106.6  43.0  3.77  4.1271   95  132
# 440   36    1  30.0   95.00  201  125.2  42.0  4.79  5.1299   85  220
# 441   36    1  19.6   71.00  250  133.2  97.0  3.00  4.5951   92   57
#
# [442 rows x 11 columns]

# %%
df = pd.read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %%
x = df.drop(columns="Y")

# %%
x.head()
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80

# %%
y = df["Y"]

# %%
y
# Out:
# 0      151
# 1       75
# 2      141
# 3      206
# 4      135
#       ...
# 437    178
# 438    104
# 439    132
# 440    220
# 441     57
# Name: Y, Length: 442, dtype: int64

# %%
# Split the test and train datasets
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %%
x_train
# Out:
#      AGE  SEX   BMI      BP   S1     S2    S3    S4      S5   S6
# 223   21    1  24.2   76.00  147   77.0  53.0  3.00  4.4427   79
# 284   60    2  24.3  103.00  141   86.6  33.0  4.00  4.6728   78
# 349   49    2  21.0   82.00  119   85.4  23.0  5.00  3.9703   74
# 67    60    2  25.0   89.67  185  120.8  46.0  4.02  4.5109   92
# 369   46    1  29.9   83.00  171  113.0  38.0  4.50  4.5850   98
# ..   ...  ...   ...     ...  ...    ...   ...   ...     ...  ...
# 426   57    2  23.2  107.33  231  159.4  41.0  5.63  5.0304  112
# 82    44    1  23.1   87.00  213  126.4  77.0  3.00  3.8712   72
# 402   79    2  23.3   88.00  186  128.4  33.0  6.00  4.8122  102
# 124   47    1  28.6   97.00  164   90.6  56.0  3.00  4.4659   88
# 167   68    1  32.8  105.67  205  116.4  40.0  5.13  5.4931  117
#
# [353 rows x 10 columns]

# %%
x_test
# Out:
#      AGE  SEX   BMI      BP   S1     S2    S3    S4      S5   S6
# 5     23    1  22.6   89.00  139   64.8  61.0  2.00  4.1897   68
# 356   47    2  23.3   90.00  195  125.8  54.0  4.00  4.3307   73
# 268   66    2  34.6  115.00  204  139.4  36.0  6.00  4.9628  109
# 430   46    1  21.1   80.00  205  144.4  42.0  5.00  4.5326   87
# 387   36    1  27.8   73.00  153  104.4  42.0  4.00  3.4965   73
# ..   ...  ...   ...     ...  ...    ...   ...   ...     ...  ...
# 407   56    1  35.0   79.33  195  140.8  42.0  4.64  4.1109   96
# 263   28    2  19.2   81.00  155   94.6  51.0  3.00  3.8501   87
# 186   26    2  30.3   89.00  218  152.2  31.0  7.00  5.1591   82
# 228   34    1  25.2   77.00  189  120.6  53.0  4.00  4.3438   79
# 411   50    1  31.8   82.00  136   69.2  55.0  2.00  4.0775   85
#
# [89 rows x 10 columns]

# %%
# Standardize the data to do the ML predection
scaler = StandardScaler()

# %%
x_train_scaled = scaler.fit_transform(x_train)

# %%
x_test_scaled = scaler.fit_transform(x_test)

# %%
x_train_scaled
# Out:
# array([[-2.17344025, -0.98036274, -0.54084494, ..., -0.84082543,
#         -0.40064813, -1.08195689],
#        [ 0.84438647,  1.0200306 , -0.51768649, ..., -0.04395219,
#          0.04406063, -1.16889766],
#        [-0.00679543,  1.0200306 , -1.28191534, ...,  0.75292105,
#         -1.31364431, -1.51666072],
#        ...,
#        [ 2.31460974,  1.0200306 , -0.74927099, ...,  1.5497943 ,
#          0.31347568,  0.91768071],
#        [-0.16155577, -0.98036274,  0.47812687, ..., -0.84082543,
#         -0.35581005, -0.29949   ],
#        [ 1.46342784, -0.98036274,  1.45078177, ...,  0.85651458,
#          1.62943482,  2.22179219]], shape=(353, 10))

# %%
ridge_model = Ridge()
lasso_model = Lasso()

# %%
# Pass the training dataset to Ridge and lasso model 
ridge_model.fit(x_train_scaled, y_train)
# Out:
# Ridge()

# %%
lasso_model.fit(x_train_scaled, y_train)
# Out:
# Lasso()

# %%
# Predect the diabetes progression predection
# Ridge
# Pass the x_test_scaled data to predict the outcome.
y_pred_ridge = ridge_model.predict(x_test_scaled)

# %%
# Predect the diabetes progression predection
# Lasso
# Pass the x_test_scalled data to predect the outcome.
y_pred_lasso = lasso_model.predict(x_test_scaled)

# %%
# Let's find out the accuracy od the model we have created by uding Mean Square Error
# with respect to the y_test and y_pred data 
mean_squared_error(y_test, y_pred_ridge)
# Out:
# 3141.837388253222

# %%
mean_absolute_error(y_test, y_pred_ridge)
# Out:
# 46.95554557794229

# %%
r2_score(y_test, y_pred_ridge)
# Out:
# 0.4454351916474346

# %% [markdown]
# #####  This means out prediction is 44 % accurate.

# %%
# Let's create pickle file for saving the model. 
# Ridge Model Pickle file
import pickle
with open ("diabetes_ridge_model.pkl", "wb") as file:
    pickle.dump((ridge_model, scaler), file)

# %%
# Let's create pickle file for saving the lasso model.
# lasso model pickle file
with open ("diabetes_lasso_model.pkl", "wb") as file:
    pickle.dump((lasso_model, scaler), file)
